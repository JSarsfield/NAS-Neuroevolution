# %%
import activations
from evolution import *
from genes import GenePool
from genome import CPPNGenome
from substrate import Substrate
import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow
from scipy import signal
import math
# %matplotlib inline

# %%
n_net_inputs = 4
n_net_outputs = 2

# %%
gene_pool = GenePool(cppn_inputs=4)
# Out:
# initial genes created

# %%
genome = CPPNGenome(gene_pool.gene_nodes_in, gene_pool.gene_nodes, gene_pool.gene_links)
genome.create_initial_graph()

# %%
net = Substrate().build_network_from_genome(genome, n_net_inputs, n_net_outputs)
# Out:
# C:\Users\JoeS\Projects\NAS-Neuroevolution\activations.py:138: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(((np.sign(freq)*(amp*(math.e**(-(0.5*(x/freq)**2)))))+vshift), dtype=torch.float32)
# C:\Users\JoeS\Projects\NAS-Neuroevolution\activations.py:142: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor((amp*np.sin(freq*x))+vshift, dtype=torch.float32)

# %%
def gaussian(x, freq=0.314, amp=2, vshift=-1):
    return (np.sign(freq)*(amp*(math.e**(-(0.5*(x/freq)**2)))))+vshift
p = []
gaussian(10, *p)
# Out:
# -1.0

# %%
def sin(x, freq=3.14, amp=1, vshift=0):
    return (amp*np.sin(freq*x))+vshift

# %%
def exp(x, freq=1, amp=0):
    return (freq*x**2)+amp

# %%
x = np.linspace(-1, 1, 1000)
#plt.plot(x, gaussian(x, 0.314, 0.5, 0.5))
plt.plot(x, gaussian(x, vshift=-0.5))
plt.plot(x, sin(x, freq=50, vshift=-1))
#plt.plot(x, exp(x, 10, 0))
plt.ylim([-1, 1])
plt.show()

# %%
genome, new_structures = copy_with_mutation(genome)
genome.create_graph()
#net = Substrate().build_network_from_genome(genome, n_net_inputs, n_net_outputs)
gene_pool.add_new_structures([genome], [new_structures])
genome.visualise_genome()
genome.visualise_cppn()
# Out:
# -0.0673086866736412   0.9634190797805786

# %%
gene_pool.gene_links
# Out:
# [<genes.GeneLink at 0x2e18a7b1160>,
#  <genes.GeneLink at 0x2e18a7b1198>,
#  <genes.GeneLink at 0x2e18a7b11d0>,
#  <genes.GeneLink at 0x2e18a7b1208>,
#  <genes.GeneLink at 0x2e18a7b12e8>,
#  <genes.GeneLink at 0x2e18a7b1320>,
#  <genes.GeneLink at 0x2e18a7b1358>,
#  <genes.GeneLink at 0x2e18a7b1390>,
#  <genes.GeneLink at 0x2e18a7b13c8>,
#  <genes.GeneLink at 0x2e18a7b1400>,
#  <genes.GeneLink at 0x2e18a7bc588>,
#  <genes.GeneLink at 0x2e18a7bcfd0>,
#  <genes.GeneLink at 0x2e18a7bceb8>,
#  <genes.GeneLink at 0x2e19a0bd9e8>,
#  <genes.GeneLink at 0x2e19a0bd4e0>,
#  <genes.GeneLink at 0x2e19a0bdcc0>,
#  <genes.GeneLink at 0x2e19a163588>,
#  <genes.GeneLink at 0x2e19a163860>,
#  <genes.GeneLink at 0x2e19a163240>,
#  <genes.GeneLink at 0x2e19a163c18>,
#  <genes.GeneLink at 0x2e19a15a390>,
#  <genes.GeneLink at 0x2e19a02dac8>,
#  <genes.GeneLink at 0x2e19a1a40b8>,
#  <genes.GeneLink at 0x2e19a1a4cc0>,
#  <genes.GeneLink at 0x2e19a1a4f98>,
#  <genes.GeneLink at 0x2e19a248320>,
#  <genes.GeneLink at 0x2e19a2489b0>,
#  <genes.GeneLink at 0x2e19a2480f0>,
#  <genes.GeneLink at 0x2e19a2bac50>,
#  <genes.GeneLink at 0x2e19a2bae10>,
#  <genes.GeneLink at 0x2e19a2f4278>,
#  <genes.GeneLink at 0x2e19a399b00>,
#  <genes.GeneLink at 0x2e19a399240>,
#  <genes.GeneLink at 0x2e19a399d68>,
#  <genes.GeneLink at 0x2e19a44f860>,
#  <genes.GeneLink at 0x2e19a44fe80>,
#  <genes.GeneLink at 0x2e19a44f9b0>,
#  <genes.GeneLink at 0x2e19a52d5f8>,
#  <genes.GeneLink at 0x2e19a52db00>,
#  <genes.GeneLink at 0x2e19a52d7b8>,
#  <genes.GeneLink at 0x2e19a5cb668>,
#  <genes.GeneLink at 0x2e19a13bc50>,
#  <genes.GeneLink at 0x2e19a5f52b0>,
#  <genes.GeneLink at 0x2e19a5b2e80>,
#  <genes.GeneLink at 0x2e19a6cac18>,
#  <genes.GeneLink at 0x2e19a6caeb8>,
#  <genes.GeneLink at 0x2e19a785550>,
#  <genes.GeneLink at 0x2e19a785b38>,
#  <genes.GeneLink at 0x2e19a785080>,
#  <genes.GeneLink at 0x2e19a38f0f0>,
#  <genes.GeneLink at 0x2e19a38f860>,
#  <genes.GeneLink at 0x2e19a38f128>,
#  <genes.GeneLink at 0x2e19a44f8d0>,
#  <genes.GeneLink at 0x2e19a38ff28>,
#  <genes.GeneLink at 0x2e19a17e278>,
#  <genes.GeneLink at 0x2e19a306c18>,
#  <genes.GeneLink at 0x2e19a306cf8>,
#  <genes.GeneLink at 0x2e19a306d30>,
#  <genes.GeneLink at 0x2e19a7cca90>,
#  <genes.GeneLink at 0x2e19a7ccb00>,
#  <genes.GeneLink at 0x2e19a7cc208>,
#  <genes.GeneLink at 0x2e19a682b70>,
#  <genes.GeneLink at 0x2e19a682da0>,
#  <genes.GeneLink at 0x2e19a682f28>,
#  <genes.GeneLink at 0x2e19a628be0>,
#  <genes.GeneLink at 0x2e19a628b38>,
#  <genes.GeneLink at 0x2e19a6289e8>,
#  <genes.GeneLink at 0x2e19a1555c0>,
#  <genes.GeneLink at 0x2e18a7bc710>,
#  <genes.GeneLink at 0x2e18a7bcac8>,
#  <genes.GeneLink at 0x2e19a2f90b8>,
#  <genes.GeneLink at 0x2e19a059710>,
#  <genes.GeneLink at 0x2e19a059da0>,
#  <genes.GeneLink at 0x2e19a523908>,
#  <genes.GeneLink at 0x2e19a523a58>,
#  <genes.GeneLink at 0x2e19a523470>,
#  <genes.GeneLink at 0x2e19a726668>,
#  <genes.GeneLink at 0x2e19a710978>,
#  <genes.GeneLink at 0x2e19a710c50>,
#  <genes.GeneLink at 0x2e19a3f6048>,
#  <genes.GeneLink at 0x2e19a3f6748>,
#  <genes.GeneLink at 0x2e19a3f6b70>,
#  <genes.GeneLink at 0x2e19a523f98>,
#  <genes.GeneLink at 0x2e19a059eb8>,
#  <genes.GeneLink at 0x2e19a7a3f98>,
#  <genes.GeneLink at 0x2e19a7116a0>,
#  <genes.GeneLink at 0x2e19a711860>,
#  <genes.GeneLink at 0x2e19a711f60>,
#  <genes.GeneLink at 0x2e199f9c160>,
#  <genes.GeneLink at 0x2e19a5ae710>,
#  <genes.GeneLink at 0x2e19a7491d0>,
#  <genes.GeneLink at 0x2e19a2c2278>,
#  <genes.GeneLink at 0x2e19a64a860>,
#  <genes.GeneLink at 0x2e19a64aba8>,
#  <genes.GeneLink at 0x2e19a7a4f28>,
#  <genes.GeneLink at 0x2e19a2c2438>,
#  <genes.GeneLink at 0x2e19a2c2cf8>,
#  <genes.GeneLink at 0x2e19a6383c8>,
#  <genes.GeneLink at 0x2e19a75bcc0>,
#  <genes.GeneLink at 0x2e19a75b160>,
#  <genes.GeneLink at 0x2e19a760710>,
#  <genes.GeneLink at 0x2e19a760a20>,
#  <genes.GeneLink at 0x2e19a7606a0>,
#  <genes.GeneLink at 0x2e19a1c1748>,
#  <genes.GeneLink at 0x2e19a53c748>,
#  <genes.GeneLink at 0x2e19a53cd68>,
#  <genes.GeneLink at 0x2e19a628940>,
#  <genes.GeneLink at 0x2e19a628a90>,
#  <genes.GeneLink at 0x2e19a628400>,
#  <genes.GeneLink at 0x2e19a765dd8>,
#  <genes.GeneLink at 0x2e19a765518>,
#  <genes.GeneLink at 0x2e19a765c18>]

# %%
net.visualise_neural_net()
